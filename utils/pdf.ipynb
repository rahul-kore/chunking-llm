# %%
import fitz
import pandas as pd
import os
from langchain.docstore.document import Document
from llm_client import LLMClient
from PIL import Image
from io import BytesIO
import base64

# %%
def get_b64_image(image_path):
    image = Image.open(image_path).convert("RGB")
    buffered = BytesIO()
    image.save(buffered, format="JPEG", quality=20)  # quality=20 is a workaround (WAR)
    b64_string = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return b64_string

def is_graph(image_path):
    # Placeholder function for graph detection logic
    # Implement graph detection algorithm here
    neva = LLMClient("neva_22b")
    b64_string = get_b64_image(image_path)
    res = neva.multimodal_invoke(b64_string, creativity = 0, quality = 9, complexity = 0, verbosity = 9).content
    print(res)
    if "graph" in res or "plot" in res or "chart" in res:
        return True
    else:
        return False

def process_graph(image_path):
    # Placeholder function for graph processing logic
    # Implement graph processing algorithm here
    # Call DePlot through the API
    deplot = LLMClient("deplot")
    b64_string = get_b64_image(image_path)
    res = deplot.multimodal_invoke(b64_string)
    deplot_description = res.content
    mixtral = LLMClient(model_name="mixtral_8x7b")
    response = mixtral.chat_with_prompt(system_prompt="Your responsibility is to explain charts. You are an expert in describing the responses of linearized tables into plain English text for LLMs to use.", 
                             prompt="Explain the following linearized table. " + deplot_description)
    full_response = ""
    for chunk in response:
        full_response += chunk
    print(full_response)
    return full_response

def extract_text_around_item(text_blocks, bbox, page_height, threshold_percentage=0.1):
    before_text, after_text = "", ""
    vertical_threshold_distance = page_height * threshold_percentage
    horizontal_threshold_distance = bbox.width * threshold_percentage  # Assuming similar threshold for horizontal distance

    for block in text_blocks:
        block_bbox = fitz.Rect(block[:4])
        vertical_distance = min(abs(block_bbox.y1 - bbox.y0), abs(block_bbox.y0 - bbox.y1))
        horizontal_overlap = max(0, min(block_bbox.x1, bbox.x1) - max(block_bbox.x0, bbox.x0))

        # Check if within vertical threshold distance and has horizontal overlap or closeness
        if vertical_distance <= vertical_threshold_distance and horizontal_overlap >= -horizontal_threshold_distance:
            if block_bbox.y1 < bbox.y0 and not before_text:
                before_text = block[4]
            elif block_bbox.y0 > bbox.y1 and not after_text:
                after_text = block[4]
                break

    return before_text, after_text

# %%
def process_text_blocks(text_blocks):
    char_count_threshold = 500  # Threshold for the number of characters in a group
    current_group = []
    grouped_blocks = []
    current_char_count = 0

    for block in text_blocks:
        if block[-1] == 0:  # Check if the block is of text type
            block_text = block[4]
            block_char_count = len(block_text)

            if current_char_count + block_char_count <= char_count_threshold:
                current_group.append(block)
                current_char_count += block_char_count
            else:
                if current_group:
                    grouped_content = "\n".join([b[4] for b in current_group])
                    grouped_blocks.append((current_group[0], grouped_content))
                current_group = [block]
                current_char_count = block_char_count

    # Append the last group
    if current_group:
        grouped_content = "\n".join([b[4] for b in current_group])
        grouped_blocks.append((current_group[0], grouped_content))

    return grouped_blocks

def parse_all_tables(filename, page, pagenum, text_blocks, ongoing_tables):
    table_docs = []
    table_bboxes = []
    ctr = 1
    try:
        tables = page.find_tables(horizontal_strategy = "lines_strict", vertical_strategy = "lines_strict")
    except Exception as e:
        print(f"Error during table extraction: {e}")
        
        return table_docs, table_bboxes, ongoing_tables
    if tables:
        for tab in tables:
            if tab.header.external:
                # Check if this table is a continuation of a table from a previous page
                previous_table = ongoing_tables.get(pagenum - 1, None)
                if previous_table:
                    # Merge the current table with the previous part
                    combined_df = pd.concat([previous_table['dataframe'], tab.to_pandas()])
                    ongoing_tables[pagenum] = {"dataframe": combined_df, "bbox": bbox}
                continue
            if not tab.header.external:
                pandas_df = tab.to_pandas()
                tablerefdir = os.path.join(os.getcwd(), "vectorstore/table_references")
                if not os.path.exists(tablerefdir):
                    os.makedirs(tablerefdir)
                df_xlsx_path = os.path.join(tablerefdir, f"table{ctr}-page{pagenum}.xlsx")
                pandas_df.to_excel(df_xlsx_path)
                bbox = fitz.Rect(tab.bbox)
                table_bboxes.append(bbox)

                # Find text around the table
                before_text, after_text = extract_text_around_item(text_blocks, bbox, page.rect.height)

                table_img = page.get_pixmap(clip=bbox)
                table_img_path = os.path.join(tablerefdir, f"table{ctr}-page{pagenum}.jpg")
                
                # table_img.save(table_img_path)
                # img = Image.open(table_img_path)
                # img.show()
                # Convert the Pixmap to a PIL Image
                pil_image = Image.frombytes("RGB", [table_img.width, table_img.height], table_img.samples)

                # Save the image with higher DPI for better quality
                dpi_factor = 100  # Adjust this factor as needed to improve quality
                pil_image.save(table_img_path, dpi=(300 * dpi_factor, 300 * dpi_factor))
                # Open and display the image
                img = Image.open(table_img_path)
                img.show()
                description = process_graph(table_img_path)
                ctr += 1

                caption = before_text.replace("\n", " ") + description + after_text.replace("\n", " ")
                if before_text == "" and after_text == "":
                    caption = " ".join(tab.header.names)


                table_metadata = {
                    "source": f"{filename[:-4]}-page{pagenum}-table{ctr}",
                    "dataframe": df_xlsx_path,
                    "image": table_img_path,
                    "caption": caption,
                    "type": "table",
                    "page_num": pagenum
                }
                all_cols = ", ".join(list(pandas_df.columns.values))
                
                doc = Document(page_content="This is a table with the caption: " + caption + f"\nThe columns are {all_cols}", metadata=table_metadata)
                table_docs.append(doc)
                
                print(table_docs)
    return table_docs, table_bboxes, ongoing_tables

def parse_all_images(filename, page, pagenum, text_blocks):
    image_docs = []
    image_info_list = page.get_image_info(xrefs=True)
    page_rect = page.rect  # Get the dimensions of the page

    for image_info in image_info_list:
        xref = image_info['xref']
        if xref == 0:
            continue  # Skip inline images or undetectable images

        img_bbox = fitz.Rect(image_info['bbox'])
        # Check if the image size is at least 5% of the page size in any dimension
        if img_bbox.width < page_rect.width / 20 or img_bbox.height < page_rect.height / 20:
            continue  # Skip very small images

        # Extract and save the image
        extracted_image = page.parent.extract_image(xref)
        image_data = extracted_image["image"]
        imgrefpath = os.path.join(os.getcwd(), "vectorstore/image_references")
        if not os.path.exists(imgrefpath):
            os.makedirs(imgrefpath)
        image_path = os.path.join(imgrefpath, f"image{xref}-page{pagenum}.png")
        with open(image_path, "wb") as img_file:
            img_file.write(image_data)

        # Find text around the image
        before_text, after_text = extract_text_around_item(text_blocks, img_bbox, page.rect.height)
        # skip images without a caption, they are likely just some logo or graphics
        if before_text == "" and after_text == "":
            continue

        # Process the image if it's a graph
        image_description = " "
        if is_graph(image_path):
            image_description = process_graph(image_path)

        # Combine the texts to form a caption
        caption = before_text.replace("\n", " ") + image_description + after_text.replace("\n", " ")

        image_metadata = {
            "source": f"{filename[:-4]}-page{pagenum}-image{xref}",
            "image": image_path,
            "caption": caption,
            "type": "image",
            "page_num": pagenum
        }
        image_docs.append(Document(page_content="This is an image with the caption: " + caption, metadata=image_metadata))
    return image_docs

def get_pdf_documents(filepath):
    all_pdf_documents = []
    ongoing_tables = {}
    try:
        f = fitz.open(filepath)
    except Exception as e:
        print(f"Error opening or processing the PDF file: {e}")
        return []

    for i in range(len(f)):
        page = f[i]
        page_docs = []

        # Process text blocks
        initial_text_blocks = page.get_text("blocks", sort=True)

        # Define thresholds for header and footer (10% of the page height)
        page_height = page.rect.height
        header_threshold = page_height * 0.1
        footer_threshold = page_height * 0.9

        # Filter out text blocks that are likely headers or footers
        text_blocks = [block for block in initial_text_blocks if block[-1] == 0 and not (block[1] < header_threshold or block[3] > footer_threshold)]

        # Group text blocks by character count
        grouped_text_blocks = process_text_blocks(text_blocks)

        # Extract tables and their bounding boxes
        table_docs, table_bboxes, ongoing_tables = parse_all_tables(filepath, page, i, text_blocks, ongoing_tables)
        page_docs.extend(table_docs)

        # Extract and process images
        image_docs = parse_all_images(filepath, page, i, text_blocks)
        page_docs.extend(image_docs)

        # Process grouped text blocks
        text_block_ctr = 0
        for heading_block, content in grouped_text_blocks:
            text_block_ctr +=1 
            heading_bbox = fitz.Rect(heading_block[:4])
            # Check if the heading or its content overlaps with table or image bounding boxes
            if not any(heading_bbox.intersects(table_bbox) for table_bbox in table_bboxes):
                bbox = {"x1": heading_block[0], "y1": heading_block[1], "x2": heading_block[2], "x3": heading_block[3]}
                text_doc = Document(page_content=f"{heading_block[4]}\n{content}", metadata={**bbox, "type": "text", "page_num": i, "source": f"{filepath[:-4]}-page{i}-block{text_block_ctr}"})
                page_docs.append(text_doc)

        all_pdf_documents.append(page_docs)

    f.close()
    return all_pdf_documents

# %%
from difflib import SequenceMatcher

def remove_duplicate_paragraphs(text):
    # Split the text into paragraphs
    paragraphs = text.split("\n\n")
    
    # Remove duplicates while preserving the order
    unique_paragraphs = []
    seen_paragraphs = set()
    for i in range(len(paragraphs) - 1):
        # Compare current paragraph with the next one
        similarity = SequenceMatcher(None, paragraphs[i], paragraphs[i+1]).ratio()
        
        # If similarity is less than 0.9 (adjust as needed), consider them as different
        if similarity < 0.9:
            if paragraphs[i] not in seen_paragraphs:
                unique_paragraphs.append(paragraphs[i])
                seen_paragraphs.add(paragraphs[i])
    
    # Add the last paragraph
    if paragraphs[-1] not in seen_paragraphs:
        unique_paragraphs.append(paragraphs[-1])
    
    # Join the unique paragraphs back into a single string
    result_text = "\n\n".join(unique_paragraphs)
    
    return result_text

# %%
import os

# Set the value of NVIDIA_API_KEY environment variable
os.environ['NVIDIA_API_KEY'] = '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'

# %%
pdf_filepath = r"E:\Projects\SA - R&D\multimodal_assistant\llm\DailyLimit-ProcedureDetailPDF.pdf"

# Call the function to extract documents from the PDF
pdf_documents_dl = get_pdf_documents(pdf_filepath)
# Out:
# The linearized table you provided lists a series of values associated with an unspecified entity. The entity likely represents a variable that can take on different numerical values.
#
# The table lists 25 distinct values that the entity can assume, ranging from a value less than 0x0A (which is typically the hexadecimal representation of the decimal number 10) to 1.778.
#
# The values are organized in a linearized format, where each column represents a different value of the entity, and each row represents a different observation or measurement.
#
# For example, the first row of the table indicates that the entity took on a value of 1.515 in one observation, while in another observation, the entity took on a value of 1.525, and so on.
#
# The last row of the table shows that the entity took on a value of 1.764 in one observation.
#
# Overall, the table provides a summary of the different values that the entity can take on, based on a series of observations or measurements.
# [Document(page_content='This is a table with the caption: A product type transfer Creating a package and linking/removing benefit accounts Activating/deactivating account access on the card Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account) The linearized table you provided lists a series of values associated with an unspecified entity. The entity likely represents a variable that can take on different numerical values.\n\nThe table lists 25 distinct values that the entity can assume, ranging from a value less than 0x0A (which is typically the hexadecimal representation of the decimal number 10) to 1.778.\n\nThe values are organized in a linearized format, where each column represents a different value of the entity, and each row represents a different observation or measurement.\n\nFor example, the first row of the table indicates that the entity took on a value of 1.515 in one observation, while in another observation, the entity took on a value of 1.525, and so on.\n\nThe last row of the table shows that the entity took on a value of 1.764 in one observation.\n\nOverall, the table provides a summary of the different values that the entity can take on, based on a series of observations or measurements.Temporary Non-PIN POS or emergency ATM limit increases \nThe columns are Customer Connection', metadata={'source': 'E:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\DailyLimit-ProcedureDetailPDF-page1-table2', 'dataframe': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page1.xlsx', 'image': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page1.jpg', 'caption': 'A product type transfer Creating a package and linking/removing benefit accounts Activating/deactivating account access on the card Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account) The linearized table you provided lists a series of values associated with an unspecified entity. The entity likely represents a variable that can take on different numerical values.\n\nThe table lists 25 distinct values that the entity can assume, ranging from a value less than 0x0A (which is typically the hexadecimal representation of the decimal number 10) to 1.778.\n\nThe values are organized in a linearized format, where each column represents a different value of the entity, and each row represents a different observation or measurement.\n\nFor example, the first row of the table indicates that the entity took on a value of 1.515 in one observation, while in another observation, the entity took on a value of 1.525, and so on.\n\nThe last row of the table shows that the entity took on a value of 1.764 in one observation.\n\nOverall, the table provides a summary of the different values that the entity can take on, based on a series of observations or measurements.Temporary Non-PIN POS or emergency ATM limit increases ', 'type': 'table', 'page_num': 1})]
# This table appears to be a chart showing various types of bank accounts and the associated fees for different services. The columns represent the type of service, and the rows represent the different types of bank accounts.
#
# The first column, "TITLE," lists the different types of bank accounts, including "Business (deposit only)," "Performance Checking," "Internet Checking," "Nobby Mutual PIC High Valid Bavings," "Savings," "Randford Credking," and "Foundation Checking."
#
# The remaining columns represent different services, with the following labels:
#
# * "ATM Hildyard"
# * "PIN POS"
# * "Non-PPM POS"
# * "PPM POS"
# * "ATM depout"
#
# For each type of bank account, the table shows a fee of 0.00 for each of the listed services. This suggests that there are no fees associated with these services for the listed bank accounts.
#
# It's worth noting that the labels for the services are a bit unclear, and it's possible that they are abbreviations or shorthand for more specific terms. For example, "ATM Hildyard" could potentially refer to a specific type of ATM or a fee associated with using an ATM of a certain type. Similarly, "PIN POS" and "PPM POS" could refer to different types of point-of-sale transactions, while "Non-PPM POS" could refer to point-of-sale transactions that do not use a specific type of payment method (PPM). "ATM depout" could refer to a fee for making a deposit at an ATM.
#
# Without further context or information about the specific terms used in this table, it's difficult to provide a more detailed explanation of the fees associated with each service for each type of bank account.
# [Document(page_content='This is a table with the caption: This table appears to be a chart showing various types of bank accounts and the associated fees for different services. The columns represent the type of service, and the rows represent the different types of bank accounts.\n\nThe first column, "TITLE," lists the different types of bank accounts, including "Business (deposit only)," "Performance Checking," "Internet Checking," "Nobby Mutual PIC High Valid Bavings," "Savings," "Randford Credking," and "Foundation Checking."\n\nThe remaining columns represent different services, with the following labels:\n\n* "ATM Hildyard"\n* "PIN POS"\n* "Non-PPM POS"\n* "PPM POS"\n* "ATM depout"\n\nFor each type of bank account, the table shows a fee of 0.00 for each of the listed services. This suggests that there are no fees associated with these services for the listed bank accounts.\n\nIt\'s worth noting that the labels for the services are a bit unclear, and it\'s possible that they are abbreviations or shorthand for more specific terms. For example, "ATM Hildyard" could potentially refer to a specific type of ATM or a fee associated with using an ATM of a certain type. Similarly, "PIN POS" and "PPM POS" could refer to different types of point-of-sale transactions, while "Non-PPM POS" could refer to point-of-sale transactions that do not use a specific type of payment method (PPM). "ATM depout" could refer to a fee for making a deposit at an ATM.\n\nWithout further context or information about the specific terms used in this table, it\'s difficult to provide a more detailed explanation of the fees associated with each service for each type of bank account.PNC Debit Cards \nThe columns are PNC Banking Cards, Col1, Col2, Col3, Col4', metadata={'source': 'E:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\DailyLimit-ProcedureDetailPDF-page2-table2', 'dataframe': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page2.xlsx', 'image': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page2.jpg', 'caption': 'This table appears to be a chart showing various types of bank accounts and the associated fees for different services. The columns represent the type of service, and the rows represent the different types of bank accounts.\n\nThe first column, "TITLE," lists the different types of bank accounts, including "Business (deposit only)," "Performance Checking," "Internet Checking," "Nobby Mutual PIC High Valid Bavings," "Savings," "Randford Credking," and "Foundation Checking."\n\nThe remaining columns represent different services, with the following labels:\n\n* "ATM Hildyard"\n* "PIN POS"\n* "Non-PPM POS"\n* "PPM POS"\n* "ATM depout"\n\nFor each type of bank account, the table shows a fee of 0.00 for each of the listed services. This suggests that there are no fees associated with these services for the listed bank accounts.\n\nIt\'s worth noting that the labels for the services are a bit unclear, and it\'s possible that they are abbreviations or shorthand for more specific terms. For example, "ATM Hildyard" could potentially refer to a specific type of ATM or a fee associated with using an ATM of a certain type. Similarly, "PIN POS" and "PPM POS" could refer to different types of point-of-sale transactions, while "Non-PPM POS" could refer to point-of-sale transactions that do not use a specific type of payment method (PPM). "ATM depout" could refer to a fee for making a deposit at an ATM.\n\nWithout further context or information about the specific terms used in this table, it\'s difficult to provide a more detailed explanation of the fees associated with each service for each type of bank account.PNC Debit Cards ', 'type': 'table', 'page_num': 2})]
# This table appears to be a comparison of different types of accounts or services, with a focus on daily changes and variations in "chwoking" (which may be a typo of "charging" or "choking", it's unclear). The leftmost column, "TITLE," contains the names of the accounts or services.
#
# The second column, labeled with a special character sequence `<0x0A>`, seems to be a separator or spacer and does not contain any meaningful data.
#
# The third column, "PMC Death Cards," is unclear in its meaning without additional context.
#
# The fourth column, "Card type Account account (ha)," appears to indicate the type of account associated with each row.
#
# The fifth column, "Daily Delta," shows the daily change in the value of each account or service. It appears that most of the values in this column are positive, indicating an increase from the previous day.
#
# The sixth column, "Favariation Chwoking," shows the variation in the "chwoking" value for each account or service. It appears that most of the values in this column are negative, indicating a decrease from the previous day.
#
# The remaining columns, "Virtual Waloff*", "Virtual Waloff Student*", "Interest Checking:Barcard Chacking", "Performance Ghacking", "Performance Scent Clacking", "Virtual Waloff, with Preference Spend", "Virtual Waloff, with Preference Setlipt, Virtual Waloff, Chacking Pus", "Virtual Bank Cheering", "Business", "Pivara Bank Cheering", "Vivitial Bank Cheering", and "Performance Scattering", appear to be specific types of accounts or services within the broader categories listed in the fourth column.
#
# Based on the data presented in the table, it appears that most of the accounts or services have experienced positive daily changes, but negative variations in "chwoking". The "PMC Death Cards" column remains unclear in its meaning.
# [Document(page_content='This is a table with the caption: This table appears to be a chart showing various types of bank accounts and the associated fees for different services. The columns represent the type of service, and the rows represent the different types of bank accounts.\n\nThe first column, "TITLE," lists the different types of bank accounts, including "Business (deposit only)," "Performance Checking," "Internet Checking," "Nobby Mutual PIC High Valid Bavings," "Savings," "Randford Credking," and "Foundation Checking."\n\nThe remaining columns represent different services, with the following labels:\n\n* "ATM Hildyard"\n* "PIN POS"\n* "Non-PPM POS"\n* "PPM POS"\n* "ATM depout"\n\nFor each type of bank account, the table shows a fee of 0.00 for each of the listed services. This suggests that there are no fees associated with these services for the listed bank accounts.\n\nIt\'s worth noting that the labels for the services are a bit unclear, and it\'s possible that they are abbreviations or shorthand for more specific terms. For example, "ATM Hildyard" could potentially refer to a specific type of ATM or a fee associated with using an ATM of a certain type. Similarly, "PIN POS" and "PPM POS" could refer to different types of point-of-sale transactions, while "Non-PPM POS" could refer to point-of-sale transactions that do not use a specific type of payment method (PPM). "ATM depout" could refer to a fee for making a deposit at an ATM.\n\nWithout further context or information about the specific terms used in this table, it\'s difficult to provide a more detailed explanation of the fees associated with each service for each type of bank account.PNC Debit Cards \nThe columns are PNC Banking Cards, Col1, Col2, Col3, Col4', metadata={'source': 'E:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\DailyLimit-ProcedureDetailPDF-page2-table2', 'dataframe': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page2.xlsx', 'image': 'e:\\Projects\\SA - R&D\\multimodal_assistant\\llm\\vectorstore/table_references\\table1-page2.jpg', 'caption': 'This table appears to be a chart showing various types of bank accounts and the associated fees for different services. The columns represent the type of service, and the rows represent the different types of bank accounts.\n\nThe first column, "TITLE," lists the different types of bank accounts, including "Business (deposit only)," "Performance Checking," "Internet Checking," "Nobby Mutual PIC High Valid Bavings," "Savings," "Randford Credking," and "Foundation Checking."\n\nThe remaining columns represent different services, with the following labels:\n\n* "ATM Hildyard"\n* "PIN POS"\n* "Non-PPM POS"\n* "PPM POS"\n* "ATM depout"\n\nFor each type of bank account, the table shows a fee of 0.00 for each of the listed services. This suggests that there are no fees associated with these services for the listed bank accounts.\n\nIt\'s worth noting that the labels for the services are a bit unclear, and it\'s possible that they are abbreviations or shorthand for more specific terms. For example, "ATM Hildyard" could potentially refer to a specific type of ATM or a fee associated with using an ATM of a certain type. Similarly, "PIN POS" and "PPM POS" could refer to different types of point-of-sale transactions, while "Non-PPM POS" could refer to point-of-sale transactions that do not use a specific type of payment method (PPM). "ATM depout" could refer to a fee for making a deposit at an ATM.\n\nWithout further context or information about the specific terms used in this table, it\'s difficult to provide a more detailed explanation of the fees associated with each service for each type of bank account.PNC Debit Cards ', 'type': 'table', 'page_num': 2}), Document(page_content='This is a table with the caption: Performance Checking $1,000 $1,000 n/a $999,999.99 This table appears to be a comparison of different types of accounts or services, with a focus on daily ...

# %%
# Initialize an empty string to store the concatenated documents
result_string = ""

# Iterate through the extracted documents
for page_documents in pdf_documents_dl:
    for document in page_documents:
        # Concatenate the page content to the result string
        result_string += document.page_content + "\n\n"

# Print the concatenated string
print(result_string)
# Out:
# Procedure
#
# Procedure
#
# Branch Banking; Business Banking; Customer Care Center
#
# Last Published Date:  9/8/2022
#
# Purpose
#
# This procedure explains debit and banking card daily limits for ATM withdrawals, deposits, PIN point-of-sale (POS) transactions and non-PIN POS transactions.
# Instructions are provided for handling customer requests to increase or decrease the daily limit for debit/banking card ATM or POS transactions.
#
#
# Overview
#
#
# Purpose of debit/banking card ATM and POS daily limits
# How card limits are determined
# Limits restrict dollar amount per day
# ATM and POS transaction limits can be changed
# Changing a customer's account product type and ATM/POS limits
# Certain card or account maintenance can result in a limit change
# Temporary Non-PIN POS or emergency ATM limit increases
# Standard daily limits for ATM, PIN POS and non-PIN POS transactions
# Before changing a cardholder's ATM or POS daily limits
#
# Purpose of debit/banking card ATM and POS daily limits
# How card limits are determined
# Limits restrict dollar amount per day
# ATM and POS transaction limits can be changed
# Changing a customer's account product type and ATM/POS limits
# Certain card or account maintenance can result in a limit change
# Temporary Non-PIN POS or emergency ATM limit increases
# Standard daily limits for ATM, PIN POS and non-PIN POS transactions
# Before changing a cardholder's ATM or POS daily limits
#
#
# How To - Change a debit/banking cardholder's daily ATM or POS limits
# Supporting Resources
#
# How To - Change a debit/banking cardholder's daily ATM or POS limits
# Supporting Resources
#
# Audience
#
# Branch; Business Banking; Customer Care Center
#
# Overview
#
# Purpose of debit/banking card ATM and POS daily limits
#
# Daily limits for ATM withdrawals, POS and non-PIN POS transactions are established to protect customers' accounts from greater losses in the event of
# unauthorized use.
#
# How card limits are determined
#
#
# Virtual Wallet  limits are set automatically with the Virtual Wallet Spend account. Non-Virtual Wallet limits are set automatically when the customer’s debit/banking
# ®
#
# Virtual Wallet  limits are set automatically with the Virtual Wallet Spend account. Non-Virtual Wallet limits are set automatically when the customer’s debit/banking
# ®
#
# card is ordered based on the highest-feature account accessed with the card. For example, a customer uses the ATM, and their debit card accesses a Standard
# account and a Performance account. The card limits will be that of the Performance account because it has higher features than the Standard account.
#
#
# Limits restrict dollar amount per day
#
# Limits restrict dollar amount per day
#
# Daily limits restrict the total dollar amount of ATM, PIN POS and non-PIN POS transactions performed by a cardholder using a
# .
# single card each calendar day
#
# For example, a card that's restricted to a $1,000 ATM withdrawal limit can be used to withdraw $1,000 each day. The limit applies whether the card is used in one
# transaction of $1,000 or ten transactions of $100.
#
# ATM and POS transaction limits can be changed
#
#
# The cardholder can request to change the debit/banking card ATM, PIN POS and non-PIN POS transaction limits through a branch or the Customer Care
# Center. Joint owners are unable to request a change to the transaction limits. For business debit/banking cards, you can
# increase or decrease the ATM and
# only
#
# The cardholder can request to change the debit/banking card ATM, PIN POS and non-PIN POS transaction limits through a branch or the Customer Care
# Center. Joint owners are unable to request a change to the transaction limits. For business debit/banking cards, you can
# increase or decrease the ATM and
# only
#
# non-PIN POS limit
# the limit change is requested by an authorized signer on the primary business checking account. Foundation Checking accounts
# eligible
#  if
# aren’t
#
#
# for ATM and non-PIN limit increases.
#
# for ATM and non-PIN limit increases.
#
# When a limit change request is submitted for:
#
#
# This is a table with the caption: A product type transfer Creating a package and linking/removing benefit accounts Activating/deactivating account access on the card Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account) The linearized table you provided contains entities and their corresponding values. However, all the values are represented as "nan," which stands for "not a number." This usually indicates that there is no valid numerical value for those entries.
#
# Here's a breakdown of the table:
#
# 1. The entity "Describe" has a value of "nan," which means there is no valid numerical value for this entity.
# 2. The entity "1." has a value of "nan" as well, indicating that there is no numerical value for this entity.
# 3. The entity "A." also has a value of "nan," meaning there is no numerical value associated with it.
# 4. The entity "P" has a value of "nan," indicating that there is no numerical value for this entity.
# 5. The entity "Card" has a value of "nan," which means there is no valid numerical value for this entity.
# 6. The entity "D" has a value of "nan," indicating that there is no numerical value for this entity.
# 7. The entity "Exc" has a value of "nan," meaning there is no numerical value associated with it.
#
# In summary, this table does not contain any meaningful numerical values for the entities listed.Temporary Non-PIN POS or emergency ATM limit increases
# The columns are Customer Connection
#
# An increase
# the
# limit, up to and including the
# limit (as shown on the
#  screen in Service Browser or the
# above
# Default
# Maximum
# Plate Maintenance
# Daily
#
# An increase
# the
# limit, up to and including the
# limit (as shown on the
#  screen in Service Browser or the
# above
# Default
# Maximum
# Plate Maintenance
# Daily
#
# ATM & Purchase Limits screen in EDGE), the request will be sent for review and will be approved or denied by 8 p.m. ET the same business day, or the
# next business day if requested after 8 p.m. ET.  You'll receive a CRISS Reference Number and can check the status of an increase request by using this
# number.
#
#
# For any completed limit change up to the maximum limit, PNC will mail the customer a debit/banking card limit change notice disclosing the new limits.
#
# For any completed limit change up to the maximum limit, PNC will mail the customer a debit/banking card limit change notice disclosing the new limits.
#
# Changing a customer's account product type and ATM/POS limits
#
# In most instances when a branch or Customer Care Center employee makes a product type change
# /
# ) for a customer, their card type and card
# (Business Consumer
#
# limits will be updated and PNC will mail a letter confirming the new card limits.
#
#
# Certain card or account maintenance can result in a limit change
#
# Certain card or account maintenance can result in a limit change
#
# Debit/banking card limits are established based on the highest feature on the account. This means that certain maintenance performed on a card may result in a
# change to the card’s limits. The following maintenance could result in a change to the highest feature on the account, which may change the card limits:
#
#
# A product type transfer
# Creating a package and linking/removing benefit accounts
# Activating/deactivating account access on the card
# Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account)
#
# A product type transfer
# Creating a package and linking/removing benefit accounts
# Activating/deactivating account access on the card
# Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account)
#
# When a customer’s card limits change, they'll be sent a notice in the mail the business day following the card limit change. The notice lists the customer’s current
# ATM withdrawal, PIN POS and non-PIN POS card limits.
#
#
# If a customer has questions about the notice they received, review the
# . Look to see if the customer recently requested a
# service request history for their account
#
# If a customer has questions about the notice they received, review the
# . Look to see if the customer recently requested a
# service request history for their account
#
#
# product type transfer, package maintenance or to activate/deactivate account access on the debit or banking card. Any of these actions could have prompted the
# card limits to change. Additionally, when an account doesn’t have any customer activity for six months, the account status will change to inactive. This may cause
# the card limits to change, which will prompt a debit/banking card limit notice to be sent to the customer.
#
# product type transfer, package maintenance or to activate/deactivate account access on the debit or banking card. Any of these actions could have prompted the
# card limits to change. Additionally, when an account doesn’t have any customer activity for six months, the account status will change to inactive. This may cause
# the card limits to change, which will prompt a debit/banking card limit notice to be sent to the customer.
#
#
# Non-PIN POS: Call
#  to request temporary increases to a customer’s non-PIN POS limits over their
# limit, as shown on the
# Card Loss Prevention
# Maximum
#
# Non-PIN POS: Call
#  to request temporary increases to a customer’s non-PIN POS limits over their
# limit, as shown on the
# Card Loss Prevention
# Maximum
#
# screen in Service Browser or the
# screen in EDGE, up to midnight of the day of the temporary
# Plate Maintenance
# Daily ATM & Purchase Limits
#
# increase.
#
# Foundation Checking accounts
# eligible for ATM and non-PIN limit increases.
# aren’t
#
#
# ATM: See
#  for emergency requests to temporarily increase ATM limits.
# Requesting Temporary ATM Limit Increases for Customer Emergencies
#
# ATM: See
#  for emergency requests to temporarily increase ATM limits.
# Requesting Temporary ATM Limit Increases for Customer Emergencies
#
# PIN POS: Emergency limit increases to PIN POS limits
#  be performed.
# can't
#
# [Back to top]
#
# Standard daily limits for ATM, PIN POS and non-PIN POS transactions
#
# Provided below are total dollar limits for ATM, PIN POS and non-PIN POS and deposit transactions per card per calendar day for:
#
# PNC Banking Cards
# PNC Debit Cards
# PNC Gold Debit Cards (not actively sold)
#
#
#
#
# This is a table with the caption: This table appears to be a summary of various types of bank accounts and their associated fees or charges for different services. The columns represent the type of service, and the rows represent the different types of bank accounts. The values in the table are all zero, indicating that there are no fees or charges for any of the services for any of the account types.
#
# The services listed are:
#
# * ATM Hildyard: This may refer to a specific ATM location or a fee associated with using a particular ATM.
# * PIN POS: This likely refers to a fee charged for using a debit card with a Personal Identification Number (PIN) at a point-of-sale (POS) terminal.
# * Non-PPM: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * PPM: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * POB: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * ATM depout: This likely refers to a fee charged for using an ATM to withdraw cash.
#
# The account types listed are:
#
# * Business (deposit only): This is a type of bank account for businesses that can only be used for making deposits.
# * Performance Checking: This is a type of checking account that may offer additional features or benefits, such as higher interest rates or lower fees.
# * Internet Checking: This is a type of checking account that is accessed and managed online.
# * Nobby Morvil: This is not a commonly used term for a bank account, so it is unclear what it refers to.
# * PIC High Yield Bavings: This is not a commonly used term for a bank account, so it is unclear what it refers to. It could be a type of savings account that offers a high interest rate.
# * Savings: This is a type of bank account that is designed for saving money.
# * Randford Cheeking: This is not a commonly used term for a bank account, so it is unclear what it refers to.
# * Foundation Checking: This is a type of checking account that may be offered by a charitable foundation or non-profit organization. It may offer additional features or benefits, such as lower fees or the ability to donate to charity.PNC Debit Cards
# The columns are PNC Banking Cards, Col1, Col2, Col3, Col4
#
# This is a table with the caption: Performance Checking $1,000 $1,000 n/a $999,999.99 This linearized table appears to represent data for various banking or financial services, with each row representing a different service or offering. The columns represent different metrics or attributes associated with each service. Here's a plain English explanation of the table:
#
# * The first column, "TITLE," provides a name or description for each service. Examples include "Favardazian Chukwu," "Virtual Wal-Mart/Interest Checking," and "Gazidazin Chukwu."
# * The second column, labeled with the hexadecimal code "<0x0A>," appears to be a numerical value, but it's unclear what this value represents without additional context. For example, the value in this column for the first row is "1900."
# * The third column, "PMC<0x0A>GSPC," also contains numerical values. It appears that all of the values in this column are "12000."
# * The fourth column, "BPW<0x0A>Villar<0x0A>Att.," contains numerical values that range from 11000 to 11000, with no variation between rows.
# * The fifth column, "PNC<0x0A>ATM<0x0A>Hind," contains numerical values that are all 11000.
# * The sixth column, "PNC<0x0A>POS," contains numerical values that are all 8999.
# * The seventh column, "Non-PAN<0x0A>FOS," contains numerical values that are all 8999.
# * The eighth column, "ATM<0x0A>ATM<0x0A>export," contains numerical values that are all 8999.
# * The ninth column, "Favardazian Chukwu," contains numerical values that are all 1000, except for the first row, which has a value of 1900.
# * The tenth column, "Chukwu," contains numerical values that are all 1000.
#
# It's worth noting that many of the service names in the "TITLE" column appear to be repeated multiple times, with different numerical values in the subsequent columns. It's possible that these repeated names represent different variations or versions of the same service, with different features or pricing structures. However, without additional context or information, it's difficult to say for sure.PNC Gold Debit Cards (not actively sold products)
# The columns are PNC Debit Cards, Col1, Col2, Col3, Col4
#
# This is a table with the caption: $1,500 $2,000 $10,000 $999,999.99 This linearized table appears to represent data for various types of PMC Gold Debit Cards, as well as some other related products or services. The leftmost column indicates the year, and the rows below it list the different types of cards or services. The remaining columns represent various features or characteristics of each card or service, with a value of 1 indicating that the feature is present and a value of 0 indicating that it is not.
#
# Here is a summary of the data in the table:
#
# * In the year 2011, PMC Gold Debit Cards came in two varieties: one with an annual fee and one without. The annual fee was removed for both varieties on December 8 of that year.
# * There is also a "Gold Premium Plan" with no annual fee.
# * There is a "Gard type/highnot account/mann" service, which is not present in any of the years listed.
# * There are several other services or features that are not present in any of the years listed, such as "Bailly belts," "ATM/po5," "Gold (Pittsburgh only: no longer in service)," "Daily Better," "ATM/holiday," and "PMC Gold Card/Cold Card/be60/lycco/lycco."
#
# It's worth noting that the table does not provide a complete picture of the PMC Gold Debit Cards or the other services listed. For example, it does not indicate what the "Gard type/highnot account/mann" service is, or what the "Daily Better" or "ATM/holiday" services entail. Additionally, the table does not provide any information about the availability or pricing of these products or services.
# The columns are PNC Gold Debit Cards (not actively sold products), Col1, Col2, Col3, Col4
#
# Before changing a cardholder's ATM or POS daily limits
#
# Before changing a cardholder's ATM or POS daily limits
#
# Before taking any action in EDGE/Service Browser/SPIRIT to change a debit/banking card’s ATM, PIN POS or non-PIN POS limit:
#
# 1.
#
# Follow existing customer identification procedures - Verify that the customer who is requesting the maintenance is the cardholder for a personal
#
#  or an authorized signer for a
# .
# account
# business account
#
# 2.
#
#
# Conduct a
# thorough review of the customer’s existing accounts -
# Check for alerts and review contact history for suspicious or unusual activity to
#
# Conduct a
# thorough review of the customer’s existing accounts -
# Check for alerts and review contact history for suspicious or unusual activity to
#
# 3.
#
#
# determine if there’s any reason the debit/banking card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or
# ATM fraud). If there is anything suspicious, refer the situation to your manager.
# Look for recent address changes - Look for a recent address change, which
# indicate a possible fraud attempt because suspects often act by
# could
#
# determine if there’s any reason the debit/banking card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or
# ATM fraud). If there is anything suspicious, refer the situation to your manager.
# Look for recent address changes - Look for a recent address change, which
# indicate a possible fraud attempt because suspects often act by
# could
#
#
# calling to change customer/account information to avoid direct contact with a branch employee who might recognize the individual isn't the actual
# customer.
#
# calling to change customer/account information to avoid direct contact with a branch employee who might recognize the individual isn't the actual
# customer.
#
# If anything seems
# (such as unusual transactions around the time the address change took place),
# continue with the debit/banking card
# suspicious
# don't
#
# transaction daily limit change.
#
#
#
# Customer Connection
#
#
# If you can't complete the card maintenance due to suspicious or unusual activity, tell the customer you can't complete the card maintenance at this time. If
# the customer seems upset, apologize for any inconvenience and refer the situation to your manager.  If the activity is determined to be suspicious or
# fraudulent, refer to
#  to determine whether reporting is necessary.
# Reporting Suspected Fraud and Other Incidents
#
# If you can't complete the card maintenance due to suspicious or unusual activity, tell the customer you can't complete the card maintenance at this time. If
# the customer seems upset, apologize for any inconvenience and refer the situation to your manager.  If the activity is determined to be suspicious or
# fraudulent, refer to
#  to determine whether reporting is necessary.
# Reporting Suspected Fraud and Other Incidents
#
#
# Managers/team leaders: Talk to the customer about the debit/banking card maintenance request and properly identify the customer. Conduct a thorough
# review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any reason the
# card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud).
#  around whether
# Use your discretion
#
# Managers/team leaders: Talk to the customer about the debit/banking card maintenance request and properly identify the customer. Conduct a thorough
# review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any reason the
# card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud).
#  around whether
# Use your discretion
#
#
# to process the limit change. Document your findings and your action taken in
#  and
# .
# Shared Notes
# Contact History
#
# to process the limit change. Document your findings and your action taken in
#  and
# .
# Shared Notes
# Contact History
#
# 1.
#
# Determine if there's a status code/card restriction on the card - If the
# field shows that the card has a
# Current Code/Hot Code/Card Restriction
#
#  assigned to it (also referred to as a hot or warm code), you won't be able to process any card maintenance.
# status code/card restriction
#
# 1.
#
#
# See
#  for information on each status code/card restriction and
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
#
# See
#  for information on each status code/card restriction and
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
#
# instruction on having them removed. Once the code is removed, if applicable, you can process the needed card maintenance.
#
# 2.
#
# Determine if the card is locked with PNC Easy Lock - The PNC Easy Lock must be removed from the card before submitting a limit change request.
#
#
# Use caution and properly identify the customer before removing the lock as a limit change request for a locked card may indicate fraud. See
# Placing or
#
# Use caution and properly identify the customer before removing the lock as a limit change request for a locked card may indicate fraud. See
# Placing or
#
#  for steps to remove the lock.
# Removing PNC Easy Lock
#
# [Back to top]
#
# How To
#
#
# To make a
#  to a customer's limits, refer to the steps below.  To make a
# , see
# permanent change
#  temporary change
# Temporary Non-PIN POS or emergency ATM
#
# To make a
#  to a customer's limits, refer to the steps below.  To make a
# , see
# permanent change
#  temporary change
# Temporary Non-PIN POS or emergency ATM
#
# .
# limit increases
#
# : Customer Care Center employees
# use EDGE Sales and Servicing Platform (SSP) for processing the request. Only use other
# Important for consumer only
# must
#
# systems when there's an EDGE outage or system limitation.
#
#
# 1.
#
# Take action depending on the system you’re using and your employee role:
#
#
# EDGE: Access the
# screen for the specific debit card.
# Financial Account
#
# EDGE: Access the
# screen for the specific debit card.
# Financial Account
#
# 1.
# 2.
#
# Service Browser:
#
# Platform employees: From the
#  applet, click to select the appropriate debit/banking card.
# Other Services
#
# 1.
# 2.
#
# Tellers: Enter the banking/debit card number.
#
# 3.
#
# SPIRIT: Access the
# .
# Debit Card Notebook
#
# 2.
#
# Review
# or
# . Thoroughly investigate any comments or alerts related to fraudulent activity or deliberate misuse of the card.
# Card Comments
# Comments
#
#
#   Customer Connection
# If any comment, alert or activity is suspicious,
# continue with the maintenance. Tell the customer you understand the request but you can't complete
# don't
#
#   Customer Connection
# If any comment, alert or activity is suspicious,
# continue with the maintenance. Tell the customer you understand the request but you can't complete
# don't
#
# the card maintenance at this time. If the customer seems upset, apologize for any inconvenience and refer the situation to your manager. If the activity is
# determined to be suspicious or fraudulent, refer to
#  to determine whether reporting is necessary.
# Reporting Suspected Fraud and Other Incidents
#
#
# Managers/team leaders: Talk to the customer about their debit/banking card maintenance request and properly identify the customer. Conduct a
# thorough review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any
# reason the card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud). If there’s a Current
#
# Managers/team leaders: Talk to the customer about their debit/banking card maintenance request and properly identify the customer. Conduct a
# thorough review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any
# reason the card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud). If there’s a Current
#
#
# on the card, you can contact the department that placed the code to discuss having the code removed.
# around
# Status Code
# Use your discretion
#
# on the card, you can contact the department that placed the code to discuss having the code removed.
# around
# Status Code
# Use your discretion
#
# whether to continue with the debit/banking card maintenance. Document your findings and your action taken in
# and
# .
# Shared Notes
# Contact History
#
# 1.
#
# If there's no status code on the card and no suspicious activity is detected:
#
# 1.
#
# EDGE:
#
# From the
#  for the specific debit card, click
#  on the right side of the screen.
#  Financial Account
# Service Request
#
#
# Select
# in the
#  field.
# Debit/Banking Card Servicing
# Service Area
#
# Select
# in the
#  field.
# Debit/Banking Card Servicing
# Service Area
#
# Select
#  in the
#  field.
# Change Card Limits
# Service Action
#
# Click
# .
# Create
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
#
# Review the existing limits with the customer.
# Delete the
# ,
#  or
#  amount you want to change, enter the cardholder's
#  and click
# ATM PIN Purchase
# Non-PIN Purchase
# requested limits
#
# 7.
#
# Next.
# Review the
# with the customer, then click
# .
#  Customer Talking Points
# Submit
#
# 1.
#
# Service Browser:
#
#
# Click the
# view.
# Banking/Debit Card Maint
#
# Click the
# view.
# Banking/Debit Card Maint
#
# Click
# .
# Plate Maintenance
#
# Select
# .
# ATM, PIN, & Non PIN POS Limit Changes
#
# 1.
# 2.
# 3.
# 4.
# 5.
#
# Review the existing limits with the customer.
# Type the cardholder's
#  and click
# .
# requested limits
# Submit
#
# 2.
#
# SPIRIT:
#
# Click the
# .
# Maintenance tab
#
# In the
# Maintenance Type field, click
# Card Related.
#
# In the
#  field, click
# .
# Maintenance Activity
# Change Card Limits
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
#
#
# Click Select...
# Review the existing limits with the customer.
# Type the cardholder's
#  and click
# .
# requested limits
# Submit
#
# Click Select...
# Review the existing limits with the customer.
# Type the cardholder's
#  and click
# .
# requested limits
# Submit
#
# [Back to top]
#
# Supporting Resources
#
#
# This is a table with the caption: Related Topics Assisting Customers with Travel Notification on Debit and Credit Cards
# Customer’s Debit/Banking Card Is Being Declined or Not Working
# PNC Debit/Banking Card Maintenance Overview
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
# Identifying Red Flags That Indicate Suspicious Activity
# Types of ATMs and Features Available
# The columns are Related Topics, Assisting Customers with Travel Notification on Debit and Credit Cards
# Customer’s Debit/Banking Card Is Being Declined or Not Working
# PNC Debit/Banking Card Maintenance Overview
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
# Identifying Red Flags That Indicate Suspicious Activity
# Types of ATMs and Features Available

# %%
corpse = remove_duplicate_paragraphs(result_string)
# Out:
# Procedure
#
# Branch Banking; Business Banking; Customer Care Center
#
# Last Published Date:  9/8/2022
#
# Purpose
#
# This procedure explains debit and banking card daily limits for ATM withdrawals, deposits, PIN point-of-sale (POS) transactions and non-PIN POS transactions.
# Instructions are provided for handling customer requests to increase or decrease the daily limit for debit/banking card ATM or POS transactions.
#
#
# Overview
#
# Purpose of debit/banking card ATM and POS daily limits
# How card limits are determined
# Limits restrict dollar amount per day
# ATM and POS transaction limits can be changed
# Changing a customer's account product type and ATM/POS limits
# Certain card or account maintenance can result in a limit change
# Temporary Non-PIN POS or emergency ATM limit increases
# Standard daily limits for ATM, PIN POS and non-PIN POS transactions
# Before changing a cardholder's ATM or POS daily limits
#
# How To - Change a debit/banking cardholder's daily ATM or POS limits
# Supporting Resources
#
# Audience
#
# Branch; Business Banking; Customer Care Center
#
# Purpose of debit/banking card ATM and POS daily limits
#
# Daily limits for ATM withdrawals, POS and non-PIN POS transactions are established to protect customers' accounts from greater losses in the event of
# unauthorized use.
#
# How card limits are determined
#
# Virtual Wallet  limits are set automatically with the Virtual Wallet Spend account. Non-Virtual Wallet limits are set automatically when the customer’s debit/banking
# ®
#
# card is ordered based on the highest-feature account accessed with the card. For example, a customer uses the ATM, and their debit card accesses a Standard
# account and a Performance account. The card limits will be that of the Performance account because it has higher features than the Standard account.
#
# Limits restrict dollar amount per day
#
# Daily limits restrict the total dollar amount of ATM, PIN POS and non-PIN POS transactions performed by a cardholder using a
# .
# single card each calendar day
#
# For example, a card that's restricted to a $1,000 ATM withdrawal limit can be used to withdraw $1,000 each day. The limit applies whether the card is used in one
# transaction of $1,000 or ten transactions of $100.
#
# ATM and POS transaction limits can be changed
#
# The cardholder can request to change the debit/banking card ATM, PIN POS and non-PIN POS transaction limits through a branch or the Customer Care
# Center. Joint owners are unable to request a change to the transaction limits. For business debit/banking cards, you can
# increase or decrease the ATM and
# only
#
# non-PIN POS limit
# the limit change is requested by an authorized signer on the primary business checking account. Foundation Checking accounts
# eligible
#  if
# aren’t
#
# for ATM and non-PIN limit increases.
#
# When a limit change request is submitted for:
#
#
# This is a table with the caption: A product type transfer Creating a package and linking/removing benefit accounts Activating/deactivating account access on the card Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account) The linearized table you provided contains entities and their corresponding values. However, all the values are represented as "nan," which stands for "not a number." This usually indicates that there is no valid numerical value for those entries.
#
# Here's a breakdown of the table:
#
# 1. The entity "Describe" has a value of "nan," which means there is no valid numerical value for this entity.
# 2. The entity "1." has a value of "nan" as well, indicating that there is no numerical value for this entity.
# 3. The entity "A." also has a value of "nan," meaning there is no numerical value associated with it.
# 4. The entity "P" has a value of "nan," indicating that there is no numerical value for this entity.
# 5. The entity "Card" has a value of "nan," which means there is no valid numerical value for this entity.
# 6. The entity "D" has a value of "nan," indicating that there is no numerical value for this entity.
# 7. The entity "Exc" has a value of "nan," meaning there is no numerical value associated with it.
#
# In summary, this table does not contain any meaningful numerical values for the entities listed.Temporary Non-PIN POS or emergency ATM limit increases
# The columns are Customer Connection
#
# An increase
# the
# limit, up to and including the
# limit (as shown on the
#  screen in Service Browser or the
# above
# Default
# Maximum
# Plate Maintenance
# Daily
#
# ATM & Purchase Limits screen in EDGE), the request will be sent for review and will be approved or denied by 8 p.m. ET the same business day, or the
# next business day if requested after 8 p.m. ET.  You'll receive a CRISS Reference Number and can check the status of an increase request by using this
# number.
#
# For any completed limit change up to the maximum limit, PNC will mail the customer a debit/banking card limit change notice disclosing the new limits.
#
# Changing a customer's account product type and ATM/POS limits
#
# In most instances when a branch or Customer Care Center employee makes a product type change
# /
# ) for a customer, their card type and card
# (Business Consumer
#
# limits will be updated and PNC will mail a letter confirming the new card limits.
#
# Certain card or account maintenance can result in a limit change
#
# Debit/banking card limits are established based on the highest feature on the account. This means that certain maintenance performed on a card may result in a
# change to the card’s limits. The following maintenance could result in a change to the highest feature on the account, which may change the card limits:
#
#
# A product type transfer
# Creating a package and linking/removing benefit accounts
# Activating/deactivating account access on the card
# Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account)
#
# A product type transfer
# Creating a package and linking/removing benefit accounts
# Activating/deactivating account access on the card
# Account status change (e.g., the account status changes to inactive, which could change the highest feature on the account)
#
# When a customer’s card limits change, they'll be sent a notice in the mail the business day following the card limit change. The notice lists the customer’s current
# ATM withdrawal, PIN POS and non-PIN POS card limits.
#
# If a customer has questions about the notice they received, review the
# . Look to see if the customer recently requested a
# service request history for their account
#
# product type transfer, package maintenance or to activate/deactivate account access on the debit or banking card. Any of these actions could have prompted the
# card limits to change. Additionally, when an account doesn’t have any customer activity for six months, the account status will change to inactive. This may cause
# the card limits to change, which will prompt a debit/banking card limit notice to be sent to the customer.
#
# Non-PIN POS: Call
#  to request temporary increases to a customer’s non-PIN POS limits over their
# limit, as shown on the
# Card Loss Prevention
# Maximum
#
# screen in Service Browser or the
# screen in EDGE, up to midnight of the day of the temporary
# Plate Maintenance
# Daily ATM & Purchase Limits
#
# increase.
#
# Foundation Checking accounts
# eligible for ATM and non-PIN limit increases.
# aren’t
#
# ATM: See
#  for emergency requests to temporarily increase ATM limits.
# Requesting Temporary ATM Limit Increases for Customer Emergencies
#
# PIN POS: Emergency limit increases to PIN POS limits
#  be performed.
# can't
#
# [Back to top]
#
# Standard daily limits for ATM, PIN POS and non-PIN POS transactions
#
# Provided below are total dollar limits for ATM, PIN POS and non-PIN POS and deposit transactions per card per calendar day for:
#
# PNC Banking Cards
# PNC Debit Cards
# PNC Gold Debit Cards (not actively sold)
#
#
#
#
# This is a table with the caption: This table appears to be a summary of various types of bank accounts and their associated fees or charges for different services. The columns represent the type of service, and the rows represent the different types of bank accounts. The values in the table are all zero, indicating that there are no fees or charges for any of the services for any of the account types.
#
# The services listed are:
#
# * ATM Hildyard: This may refer to a specific ATM location or a fee associated with using a particular ATM.
# * PIN POS: This likely refers to a fee charged for using a debit card with a Personal Identification Number (PIN) at a point-of-sale (POS) terminal.
# * Non-PPM: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * PPM: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * POB: This is not a commonly used term in banking, so it is unclear what it refers to. It could be a specific fee or charge.
# * ATM depout: This likely refers to a fee charged for using an ATM to withdraw cash.
#
# The account types listed are:
#
# * Business (deposit only): This is a type of bank account for businesses that can only be used for making deposits.
# * Performance Checking: This is a type of checking account that may offer additional features or benefits, such as higher interest rates or lower fees.
# * Internet Checking: This is a type of checking account that is accessed and managed online.
# * Nobby Morvil: This is not a commonly used term for a bank account, so it is unclear what it refers to.
# * PIC High Yield Bavings: This is not a commonly used term for a bank account, so it is unclear what it refers to. It could be a type of savings account that offers a high interest rate.
# * Savings: This is a type of bank account that is designed for saving money.
# * Randford Cheeking: This is not a commonly used term for a bank account, so it is unclear what it refers to.
# * Foundation Checking: This is a type of checking account that may be offered by a charitable foundation or non-profit organization. It may offer additional features or benefits, such as lower fees or the ability to donate to charity.PNC Debit Cards
# The columns are PNC Banking Cards, Col1, Col2, Col3, Col4
#
# This is a table with the caption: Performance Checking $1,000 $1,000 n/a $999,999.99 This linearized table appears to represent data for various banking or financial services, with each row representing a different service or offering. The columns represent different metrics or attributes associated with each service. Here's a plain English explanation of the table:
#
# * The first column, "TITLE," provides a name or description for each service. Examples include "Favardazian Chukwu," "Virtual Wal-Mart/Interest Checking," and "Gazidazin Chukwu."
# * The second column, labeled with the hexadecimal code "<0x0A>," appears to be a numerical value, but it's unclear what this value represents without additional context. For example, the value in this column for the first row is "1900."
# * The third column, "PMC<0x0A>GSPC," also contains numerical values. It appears that all of the values in this column are "12000."
# * The fourth column, "BPW<0x0A>Villar<0x0A>Att.," contains numerical values that range from 11000 to 11000, with no variation between rows.
# * The fifth column, "PNC<0x0A>ATM<0x0A>Hind," contains numerical values that are all 11000.
# * The sixth column, "PNC<0x0A>POS," contains numerical values that are all 8999.
# * The seventh column, "Non-PAN<0x0A>FOS," contains numerical values that are all 8999.
# * The eighth column, "ATM<0x0A>ATM<0x0A>export," contains numerical values that are all 8999.
# * The ninth column, "Favardazian Chukwu," contains numerical values that are all 1000, except for the first row, which has a value of 1900.
# * The tenth column, "Chukwu," contains numerical values that are all 1000.
#
# It's worth noting that many of the service names in the "TITLE" column appear to be repeated multiple times, with different numerical values in the subsequent columns. It's possible that these repeated names represent different variations or versions of the same service, with different features or pricing structures. However, without additional context or information, it's difficult to say for sure.PNC Gold Debit Cards (not actively sold products)
# The columns are PNC Debit Cards, Col1, Col2, Col3, Col4
#
# This is a table with the caption: $1,500 $2,000 $10,000 $999,999.99 This linearized table appears to represent data for various types of PMC Gold Debit Cards, as well as some other related products or services. The leftmost column indicates the year, and the rows below it list the different types of cards or services. The remaining columns represent various features or characteristics of each card or service, with a value of 1 indicating that the feature is present and a value of 0 indicating that it is not.
#
# Here is a summary of the data in the table:
#
# * In the year 2011, PMC Gold Debit Cards came in two varieties: one with an annual fee and one without. The annual fee was removed for both varieties on December 8 of that year.
# * There is also a "Gold Premium Plan" with no annual fee.
# * There is a "Gard type/highnot account/mann" service, which is not present in any of the years listed.
# * There are several other services or features that are not present in any of the years listed, such as "Bailly belts," "ATM/po5," "Gold (Pittsburgh only: no longer in service)," "Daily Better," "ATM/holiday," and "PMC Gold Card/Cold Card/be60/lycco/lycco."
#
# It's worth noting that the table does not provide a complete picture of the PMC Gold Debit Cards or the other services listed. For example, it does not indicate what the "Gard type/highnot account/mann" service is, or what the "Daily Better" or "ATM/holiday" services entail. Additionally, the table does not provide any information about the availability or pricing of these products or services.
# The columns are PNC Gold Debit Cards (not actively sold products), Col1, Col2, Col3, Col4
#
# Before changing a cardholder's ATM or POS daily limits
#
# Before taking any action in EDGE/Service Browser/SPIRIT to change a debit/banking card’s ATM, PIN POS or non-PIN POS limit:
#
# 1.
#
# Follow existing customer identification procedures - Verify that the customer who is requesting the maintenance is the cardholder for a personal
#
#  or an authorized signer for a
# .
# account
# business account
#
# 2.
#
# Conduct a
# thorough review of the customer’s existing accounts -
# Check for alerts and review contact history for suspicious or unusual activity to
#
# 3.
#
# determine if there’s any reason the debit/banking card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or
# ATM fraud). If there is anything suspicious, refer the situation to your manager.
# Look for recent address changes - Look for a recent address change, which
# indicate a possible fraud attempt because suspects often act by
# could
#
# calling to change customer/account information to avoid direct contact with a branch employee who might recognize the individual isn't the actual
# customer.
#
# If anything seems
# (such as unusual transactions around the time the address change took place),
# continue with the debit/banking card
# suspicious
# don't
#
# transaction daily limit change.
#
#
#
# Customer Connection
#
# If you can't complete the card maintenance due to suspicious or unusual activity, tell the customer you can't complete the card maintenance at this time. If
# the customer seems upset, apologize for any inconvenience and refer the situation to your manager.  If the activity is determined to be suspicious or
# fraudulent, refer to
#  to determine whether reporting is necessary.
# Reporting Suspected Fraud and Other Incidents
#
# Managers/team leaders: Talk to the customer about the debit/banking card maintenance request and properly identify the customer. Conduct a thorough
# review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any reason the
# card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud).
#  around whether
# Use your discretion
#
# to process the limit change. Document your findings and your action taken in
#  and
# .
# Shared Notes
# Contact History
#
# Determine if there's a status code/card restriction on the card - If the
# field shows that the card has a
# Current Code/Hot Code/Card Restriction
#
#  assigned to it (also referred to as a hot or warm code), you won't be able to process any card maintenance.
# status code/card restriction
#
# See
#  for information on each status code/card restriction and
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
#
# instruction on having them removed. Once the code is removed, if applicable, you can process the needed card maintenance.
#
# Determine if the card is locked with PNC Easy Lock - The PNC Easy Lock must be removed from the card before submitting a limit change request.
#
# Use caution and properly identify the customer before removing the lock as a limit change request for a locked card may indicate fraud. See
# Placing or
#
#  for steps to remove the lock.
# Removing PNC Easy Lock
#
# How To
#
# To make a
#  to a customer's limits, refer to the steps below.  To make a
# , see
# permanent change
#  temporary change
# Temporary Non-PIN POS or emergency ATM
#
# .
# limit increases
#
# : Customer Care Center employees
# use EDGE Sales and Servicing Platform (SSP) for processing the request. Only use other
# Important for consumer only
# must
#
# systems when there's an EDGE outage or system limitation.
#
#
# Take action depending on the system you’re using and your employee role:
#
# EDGE: Access the
# screen for the specific debit card.
# Financial Account
#
# 1.
# 2.
#
# Service Browser:
#
# Platform employees: From the
#  applet, click to select the appropriate debit/banking card.
# Other Services
#
# Tellers: Enter the banking/debit card number.
#
# SPIRIT: Access the
# .
# Debit Card Notebook
#
# Review
# or
# . Thoroughly investigate any comments or alerts related to fraudulent activity or deliberate misuse of the card.
# Card Comments
# Comments
#
#   Customer Connection
# If any comment, alert or activity is suspicious,
# continue with the maintenance. Tell the customer you understand the request but you can't complete
# don't
#
# the card maintenance at this time. If the customer seems upset, apologize for any inconvenience and refer the situation to your manager. If the activity is
# determined to be suspicious or fraudulent, refer to
#  to determine whether reporting is necessary.
# Reporting Suspected Fraud and Other Incidents
#
# Managers/team leaders: Talk to the customer about their debit/banking card maintenance request and properly identify the customer. Conduct a
# thorough review of the customer’s account(s). Check for alerts and review contact history for suspicious or unusual activity to determine if there’s any
# reason the card maintenance shouldn't be performed (such as an alert for a stolen wallet, unsatisfactory account or ATM fraud). If there’s a Current
#
# on the card, you can contact the department that placed the code to discuss having the code removed.
# around
# Status Code
# Use your discretion
#
# whether to continue with the debit/banking card maintenance. Document your findings and your action taken in
# and
# .
# Shared Notes
# Contact History
#
# If there's no status code on the card and no suspicious activity is detected:
#
# EDGE:
#
# From the
#  for the specific debit card, click
#  on the right side of the screen.
#  Financial Account
# Service Request
#
# Select
# in the
#  field.
# Debit/Banking Card Servicing
# Service Area
#
# Select
#  in the
#  field.
# Change Card Limits
# Service Action
#
# Click
# .
# Create
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
#
# Review the existing limits with the customer.
# Delete the
# ,
#  or
#  amount you want to change, enter the cardholder's
#  and click
# ATM PIN Purchase
# Non-PIN Purchase
# requested limits
#
# 7.
#
# Next.
# Review the
# with the customer, then click
# .
#  Customer Talking Points
# Submit
#
# Service Browser:
#
# Click the
# view.
# Banking/Debit Card Maint
#
# Click
# .
# Plate Maintenance
#
# Select
# .
# ATM, PIN, & Non PIN POS Limit Changes
#
# 1.
# 2.
# 3.
# 4.
# 5.
#
# Review the existing limits with the customer.
# Type the cardholder's
#  and click
# .
# requested limits
# Submit
#
# SPIRIT:
#
# Click the
# .
# Maintenance tab
#
# In the
# Maintenance Type field, click
# Card Related.
#
# In the
#  field, click
# .
# Maintenance Activity
# Change Card Limits
#
# Click Select...
# Review the existing limits with the customer.
# Type the cardholder's
#  and click
# .
# requested limits
# Submit
#
# Supporting Resources
#
#
# This is a table with the caption: Related Topics Assisting Customers with Travel Notification on Debit and Credit Cards
# Customer’s Debit/Banking Card Is Being Declined or Not Working
# PNC Debit/Banking Card Maintenance Overview
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
# Identifying Red Flags That Indicate Suspicious Activity
# Types of ATMs and Features Available
# The columns are Related Topics, Assisting Customers with Travel Notification on Debit and Credit Cards
# Customer’s Debit/Banking Card Is Being Declined or Not Working
# PNC Debit/Banking Card Maintenance Overview
# PNC Debit/Banking Card Status Codes/Card Restrictions (Hot and Warm Codes)
# Identifying Red Flags That Indicate Suspicious Activity
# Types of ATMs and Features Available

# %%
import pandas as pd

def df_to_table_string(df):
    # Get the maximum width of each column
    col_widths = [max(df[col].astype(str).map(len).max(), len(col)) for col in df.columns]
    
    # Format the column headers
    header = " | ".join([f"{col:<{col_widths[i]}}" for i, col in enumerate(df.columns)])
    
    # Create a separator line
    separator = "-+-".join(['-' * width for width in col_widths])
    
    # Format the rows
    rows = []
    for index, row in df.iterrows():
        rows.append(" | ".join([f"{str(row[col]):<{col_widths[i]}}" for i, col in enumerate(df.columns)]))
    
    # Combine header, separator, and rows
    table_string = f"{header}\n{separator}\n" + "\n".join(rows)
    
    return table_string

# Example usage
data = pd.read_excel(r"E:\Projects\SA - R&D\chunking\vectorstore\table_references\table1-page2.xlsx")
print(data)
df = pd.DataFrame(data)
print(df_to_table_string(df))
# Out:
# Unnamed: 0 | 1 | Lawfulness, fairness &
# transparency | Personal data must be processed lawfully, fairly and in a
# transparent manner. This means we have to have informed
# people how we will use their personal data, why we need it and
# make sure we have legal grounds for processing it. For example
# we cannot send customers data to suppliers unless we have told
# them this will occur.
# 0          | 2 | Limited lawful purpose              | Personal data must be only
#            |   |                                     | collected for specified,
#            |   |                                     | explicit and legitimate
#            |   |                                     | purposes. We cannot just keep
#            |   |                                     | data for no reason.
# 1          | 3 | Data minimisation                   | Personal data must be
#            |   |                                     | adequate, relevant and limited
#            |   |                                     | to what is necessary in
#            |   |                                     | relation to the intended
#            |   |                                     | purpose. Wherever possible we
#            |   |                                     | need to reduce the personal
#            |   |                                     | data we process to minimise
#            |   |                                     | the risk – so for example does
#            |   |                                     | a customer spreadsheet really
#            |   |                                     | need their name, address,
#            |   |                                     | mobile number and so on. Why
#            |   |                                     | not just a customer number?
# 2          | 4 | Accuracy                            | Personal data must be accurate
#            |   |                                     | and, where necessary, kept up
#            |   |                                     | to date. We have to be able to
#            |   |                                     | amend, correct or delete
#            |   |                                     | personal information if
#            |   |                                     | required, so the fewer places
#            |   |                                     | data is held the easier this
#            |   |                                     | task is.
# 3          | 5 | Storage limitation                  | Personal data must not be kept
#            |   |                                     | in a form which permits
#            |   |                                     | identification for any longer
#            |   |                                     | than necessary for the given
#            |   |                                     | purpose. Unused data should be
#            |   |                                     | deleted or if we are required
#            |   |                                     | to hold it for any reason –
#            |   |                                     | consider reducing the amount
#            |   |                                     | of data held.
# 4          | 6 | Integration & Confidentiality       | Personal data must be
#            |   |                                     | processed in a manner which
#            |   |                                     | ensures its appropriate
#            |   |                                     | security. We have a legal
#            |   |                                     | obligation to ensure we have
#            |   |                                     | organisational and technical
#            |   |                                     | processes and procedures in
#            |   |                                     | place to ensure that every
#            |   |                                     | person’s data is secure,
#            |   |                                     | whether this is robust IT
#            |   |                                     | systems, locking personal data
#            |   |                                     | away or making sure personnel
#            |   |                                     | files or other data is not
#            |   |                                     | left/ lost/ sent where is can
#            |   |                                     | be seen by unauthorised
#            |   |                                     | people. As data controller we
#            |   |                                     | also have to make sure than
#            |   |                                     | when we give the data to a
#            |   |                                     | third party – they will also
#            |   |                                     | ensure its safety. We remain
#            |   |                                     | liable.
# 5          | 7 | Accountability                      | The data controller is
#            |   |                                     | responsible for, and must be
#            |   |                                     | able to demonstrate,
#            |   |                                     | compliance with the other data
#            |   |                                     | protection principles. GDPR
#            |   |                                     | requires Booker to be able to
#            |   |                                     | demonstrate that we have
#            |   |                                     | documented processes and
#            |   |                                     | procedures in place to
#            |   |                                     | demonstrate how we comply with
#            |   |                                     | GDPR. You will see a lot more
#            |   |                                     | paper and procedures around
#            |   |                                     | using personal data. These
#            |   |                                     | must be followed!
# C:\Users\Rahul.G\AppData\Local\Temp\ipykernel_10804\602340740.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wrapped_df = df.applymap(lambda x: wrap_text(x, max_col_width))

# %%
all_cols
# Out:
# 'Name, Age, City'
